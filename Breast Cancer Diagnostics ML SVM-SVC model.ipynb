# %%
"""
   Analyst : Jainam Shah
   
   Project : Breast Cancer Diagnostics Analysis
   
   Objective : Whether Patient has B OR M Diagnosis
     
"""

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
cd C:\Users\Jammy\OneDrive\Desktop\Data analysis PDFs\Datas to practice\Breast Cancer Diagnostic dataset
# Out:
# C:\Users\Jammy\OneDrive\Desktop\Data analysis PDFs\Datas to practice\Breast Cancer Diagnostic dataset

# %%
bcd = pd.read_csv("Breast cancer diagnostic dataset.csv")

# %%
bcd.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
bcd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
bcd.drop(["Unnamed: 32"],axis = 1, inplace = True)

# %%
bcd.shape
# Out:
# (569, 32)

# %%
bcd.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# ###### as checked in csv sheet through filter there are no unique values or anomalys which would need handling

# %%
bcd.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# #### Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_scal = MinMaxScaler()

# %%
new_bcd = bcd

# %%
new_bcd.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
new_bcd[['id','radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst']] = min_scal.fit_transform(new_bcd[['id','radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst']])

# %%
new_bcd.describe()
# Out:
#                id  radius_mean  texture_mean  perimeter_mean   area_mean  \
# count  569.000000   569.000000    569.000000      569.000000  569.000000
# mean     0.033318     0.338222      0.323965        0.332935    0.216920
# std      0.137187     0.166787      0.145453        0.167915    0.149274
# min      0.000000     0.000000      0.000000        0.000000    0.000000
# 25%      0.000944     0.223342      0.218465        0.216847    0.117413
# 50%      0.000985     0.302381      0.308759        0.293345    0.172895
# 75%      0.009661     0.416442      0.408860        0.416765    0.271135
# max      1.000000     1.000000      1.000000        1.000000    1.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.394785          0.260601        0.208058             0.243137
# ...

# %% [markdown]
# #### Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lr = LabelEncoder()

# %%
new_bcd[['diagnosis']] = new_bcd[['diagnosis']].apply(lr.fit_transform)

# %%
new_bcd.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  0.000915          1     0.521037      0.022658        0.545989   0.363733
# 1  0.000915          1     0.643144      0.272574        0.615783   0.501591
# 2  0.092495          1     0.601496      0.390260        0.595743   0.449417
# 3  0.092547          1     0.210090      0.360839        0.233501   0.102906
# 4  0.092559          1     0.629893      0.156578        0.630986   0.489290
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         0.593753          0.792037        0.703140             0.731113
# 1         0.289880          0.181768        0.203608             0.348757
# 2         0.514309          0.431017        0.462512             0.635686
# 3         0.811321          0.811361        0.565604             0.522863
# 4         0.430351          0.347893        0.463918             0.518390
#
# ...

# %% [markdown]
# #### Train/Test Split

# %%
C = new_bcd[['id','radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst']]

D = new_bcd.diagnosis

# %%
C.shape
# Out:
# (569, 31)

# %%
D.shape
# Out:
# (569,)

# %%
D.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(C,D,train_size=0.7)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log = LogisticRegression()
log.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_train,Y_train)
# Out:
# 0.9673366834170855

# %%
model.score(X_test,Y_test)
# Out:
# 0.9649122807017544

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

# %%
log = [DecisionTreeClassifier, SVC,RandomForestClassifier,KNeighborsClassifier,GaussianNB]

for l in log:
    reg = l()
    reg = reg.fit(X_train,Y_train)
    print(l , 'accuracy',reg.score(X_test,Y_test))
# Out:
# <class 'sklearn.tree._classes.DecisionTreeClassifier'> accuracy 0.9239766081871345
# <class 'sklearn.svm._classes.SVC'> accuracy 0.9824561403508771
# <class 'sklearn.ensemble._forest.RandomForestClassifier'> accuracy 0.9532163742690059
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'> accuracy 0.9766081871345029
# <class 'sklearn.naive_bayes.GaussianNB'> accuracy 0.9473684210526315

# %% [markdown]
# #### SVC in SVM will be the best model for the analysis

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
svc=SVC() 
svc.fit(X_train,Y_train)
# Out:
# SVC()

# %%
y_pred=svc.predict(X_test)


print('Model accuracy score rbf  {0:0.4f}'. format(accuracy_score(Y_test, y_pred)))
# Out:
# Model accuracy score rbf  0.9825

# %%
#--------------------------------------------------------X---------------------------------------------------------------------
